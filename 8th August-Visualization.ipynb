# %% [markdown]
# # dataset SAT_Exam

# %%
pip intall missingno
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "intall" - maybe you meant "install"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")
import missingno as mino

# %%
exam=pd.read_csv("SAT_Exam.csv")

# %%
exam.head()
# Out:
#    General_knowledge   Aptitude   Mathematics   Science   SAT
# 0                  73         71            74        73  144
# 1                  93         90            60        97  186
# 2                  89         94            97        98  182
# 3                  96         93           115       110  208
# 4                  73         68            87        83  157

# %%
exam.shape
# Out:
# (96, 5)

# %%
exam.tail()
# Out:
#     General_knowledge   Aptitude   Mathematics   Science   SAT
# 91                  80         83            65        65  149
# 92                  90         88            93        98  191
# 93                  93         93            77        72  163
# 94                  80         83             6         3   78
# 95                  77         73           104       102  180

# %%
exam.describe()
# Out:
#        General_knowledge    Aptitude   Mathematics     Science          SAT
# count           96.000000   96.000000      96.00000   96.000000   96.000000
# mean            79.854167   79.916667      76.25000   76.802083  155.968750
# std             12.230229   12.189440      22.41569   22.925793   32.427881
# min             46.000000   46.000000       6.00000    3.000000   70.000000
# 25%             74.000000   74.000000      65.00000   65.000000  140.000000
# 50%             80.000000   81.000000      77.00000   79.000000  157.500000
# 75%             88.250000   89.000000      90.25000   92.000000  180.000000
# max             97.000000  101.000000     125.00000  124.000000  223.000000

# %%
exam.info() # to get information  about dimensions and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   General_knowledge   96 non-null     int64
#  1   Aptitude            96 non-null     int64
#  2   Mathematics         96 non-null     int64
#  3   Science             96 non-null     int64
#  4   SAT                 96 non-null     int64
# dtypes: int64(5)
# memory usage: 3.9 KB

# %%
exam.columns
# Out:
# Index(['General_knowledge ', 'Aptitude ', 'Mathematics ', 'Science ', 'SAT'], dtype='object')

# %%
exam.SAT
# Out:
# 0     144
# 1     186
# 2     182
# 3     208
# 4     157
#      ...
# 91    149
# 92    191
# 93    163
# 94     78
# 95    180
# Name: SAT, Length: 96, dtype: int64

# %%
pd.DataFrame(exam.kurtosis(),columns=['kurtosis'])
# Out:
#                     kurtosis
# General_knowledge   0.604407
# Aptitude            0.888228
# Mathematics         0.750723
# Science             0.655287
# SAT                 0.552747

# %%
exam.kurtosis()
# Out:
# General_knowledge     0.604407
# Aptitude              0.888228
# Mathematics           0.750723
# Science               0.655287
# SAT                   0.552747
# dtype: float64

# %%
exam.skew()
# Out:
# General_knowledge    -0.826330
# Aptitude             -0.916175
# Mathematics          -0.496929
# Science              -0.566476
# SAT                  -0.646051
# dtype: float64

# %%
exam.columns
# Out:
# Index(['General_knowledge ', 'Aptitude ', 'Mathematics ', 'Science ', 'SAT'], dtype='object')

# %%
exam.columns=exam.columns.str.replace(' ', '')
exam.columns
# Out:
# Index(['General_knowledge', 'Aptitude', 'Mathematics', 'Science', 'SAT'], dtype='object')

# %%
exam.isnull().sum()
# Out:
# General_knowledge    0
# Aptitude             0
# Mathematics          0
# Science              0
# SAT                  0
# dtype: int64

# %%
exam.isnull()
# Out:
#     General_knowledge  Aptitude  Mathematics  Science    SAT
# 0               False     False        False    False  False
# 1               False     False        False    False  False
# 2               False     False        False    False  False
# 3               False     False        False    False  False
# 4               False     False        False    False  False
# ..                ...       ...          ...      ...    ...
# 91              False     False        False    False  False
# 92              False     False        False    False  False
# 93              False     False        False    False  False
# 94              False     False        False    False  False
# 95              False     False        False    False  False
#
# [96 rows x 5 columns]

# %%
plt.figure(figsize=(10,5))
mino.matrix(exam)

# %%
# Construct box plot
sns.catplot(data=exam , kind='box' , height=10, aspect=2.5);

# %%
# Univariate analysis
# we can see most of students scored between 60-90
plt.hist(exam['Science'])
plt.xlabel("Marks")
plt.ylabel('Count')
plt.title('Science marks')
plt.show()

# %%
sns.kdeplot(exam["Science"], shade=True)
plt.xlabel('Marks')
plt.title('Science marks');

# %%
sns.kdeplot(exam["Mathematics"], shade=True)
plt.xlabel('Marks')
plt.title('Maths marks')
# Out:
# Text(0.5, 1.0, 'Maths marks')

# %%
plt.hist(exam['Mathematics'])
plt.xlabel("Marks")
plt.ylabel('Count')
plt.title('Mathematics marks')
plt.show()

# %%
sns.kdeplot(exam["Aptitude"], shade=True)
plt.xlabel('Marks')
plt.title('Aptitude marks')
# Out:
# Text(0.5, 1.0, 'Aptitude marks')

# %%
plt.hist(exam['Aptitude'])
plt.xlabel("Marks")
plt.ylabel('Count')
plt.title('Aptitude marks')
plt.show()

# %%
sns.kdeplot(exam["General_knowledge"], shade=True)
plt.xlabel('Marks')
plt.title('GK marks')
# Out:
# Text(0.5, 1.0, 'GK marks')

# %%
plt.hist(exam['General_knowledge'])
plt.xlabel("Marks")
plt.ylabel('Count')
plt.title('GK marks')
plt.show()

# %%
sns.kdeplot(exam["SAT"], shade=True)
plt.xlabel('Marks')
plt.title('SAT marks')
# Out:
# Text(0.5, 1.0, 'SAT marks')

# %%
plt.hist(exam['SAT'])
plt.xlabel("Marks")
plt.ylabel('Count')
plt.title('SAT marks')
plt.show()

# %% [markdown]
# # Bivariate Anlaysis

# %%
# Checking the relationship between 2 variables
plt.scatter(x='Science', y='SAT',data=exam)
plt.xlabel('Science')
plt.ylabel('SAT')
plt.title("relation between Science and SAT")
plt.show()
# We can see most of the science marks lie in 70-100 area and corresponding to that SAT marks lie in 140-200 area
# we can also see some of the outliers

# %%
#Checking the relation between 2 variables GK(independent varaible) and SAT(dependent variable)
plt.scatter(x='General_knowledge',y='SAT',data=exam)

# %%
exam.corr()
# Out:
#                    General_knowledge  Aptitude  Mathematics   Science  \
# General_knowledge           1.000000  0.963232     0.622769  0.640775
# Aptitude                    0.963232  1.000000     0.590701  0.607482
# Mathematics                 0.622769  0.590701     1.000000  0.976331
# Science                     0.640775  0.607482     0.976331  1.000000
# SAT                         0.838191  0.797194     0.926694  0.949496
#
#                         SAT
# General_knowledge  0.838191
# Aptitude           0.797194
# Mathematics        0.926694
# Science            0.949496
# SAT                1.000000

# %%
#For Bivariate, we also use jointplot
sns.jointplot(x='Mathematics',y="SAT",data=exam)

# %% [markdown]
# # 9th August

# %%
#by using pairplot we can see the relation between all the variable together
sns.pairplot(exam,height=2,diag_kind='kde')

# %%
exam.cov()
# Out:
#                     General_knowledge    Aptitude   Mathematics     Science   \
# General_knowledge           149.578509  143.598246    170.731579  179.665570
# Aptitude                    143.598246  148.582456    161.400000  169.762281
# Mathematics                 170.731579  161.400000    502.463158  501.734211
# Science                     179.665570  169.762281    501.734211  525.591996
# SAT                         332.426974  315.113158    673.607895  705.888487
#
#                             SAT
# General_knowledge    332.426974
# Aptitude             315.113158
# Mathematics          673.607895
# Science              705.888487
# SAT                 1051.567434

# %%
# Correlation
# 1.00 have strong corelation - light color
sns.heatmap(exam.corr(),annot=False)
